# %% [markdown]
# <a href="https://colab.research.google.com/github/Mangesh0309/Neural-Networks/blob/main/Different_YOLO11_weight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing ultralytics

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()

# %% [markdown]
# #Command Line Interface

# %% [markdown]
# Using YOLO pretrained models for predictions

# %% [markdown]
# [Explore YOLO Models](https://docs.ultralytics.com/tasks/detect/#models)

# %%
# Visualize the predicted image function
import cv2
from google.colab.patches import cv2_imshow

def show_img(image_path):
      # Function to display an image using OpenCV in colab
      image = cv2.imread(image_path)
      if image is None:
        print("ERROR: image not found")
        return

      cv2_imshow(image)

# %% [markdown]
# 1. Nano Model

# %%
# Run inference on an image with YOLO11n
# !yolo predict model = yolo11n.pt source="https://images.pexels.com/photos/36763394/pexels-photo-36763394.jpeg"

# %%
show_img('/content/runs/detect/predict-2/pexels-photo-36763394.jpg')

# %% [markdown]
# 2. Small model

# %%
# Run inference on an image with YOLO11s
# !yolo predict model = yolo11s.pt source="https://images.pexels.com/photos/36763394/pexels-photo-36763394.jpeg"

# %%
show_img('/content/runs/detect/predict-3/pexels-photo-36763394.jpg')

# %% [markdown]
# 3. Medium model

# %%
# Run inference on an image with YOLO11m
# !yolo predict model = yolo11m.pt source="https://images.pexels.com/photos/36763394/pexels-photo-36763394.jpeg"

# %%
show_img('/content/runs/detect/predict-4/pexels-photo-36763394.jpg')

# %% [markdown]
# 4. Large model

# %%
# Run inference on an image with YOLO11l
# !yolo predict model = yolo11l.pt source="https://images.pexels.com/photos/36763394/pexels-photo-36763394.jpeg"

# %%
show_img('/content/runs/detect/predict-5/pexels-photo-36763394.jpg')

# %% [markdown]
# 5. Extra large model

# %%
# Run inference on an image with YOLO1x
# !yolo predict model = yolo11x.pt source="https://images.pexels.com/photos/36763394/pexels-photo-36763394.jpeg"

# %%
show_img('/content/runs/detect/predict-6/pexels-photo-36763394.jpg')
